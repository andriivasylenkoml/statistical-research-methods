# %% [markdown]
# <a href="https://colab.research.google.com/github/AndriiVasylenkoML/statistical-research-methods/blob/main/lab3_definition_distribution_law.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import cumfreq

# %%
x2 = np.array([2.11, 92.22, 82.43, 13.70, 53.42, 72.63, 11.723, 84.2])

n_classes = 5
hist, bin_edges = np.histogram(x2, bins=n_classes)
class_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

print(f"""
hist, bin_edges = {np.histogram(x2, bins=n_classes)}
\ncass_centers = ({bin_edges[:-1]} + {bin_edges[1:]}) / 2
""")
# Out:
# hist, bin_edges = (array([3, 0, 1, 1, 3]), array([ 2.11 , 20.132, 38.154, 56.176, 74.198, 92.22 ]))
#
# cass_centers = ([ 2.11  20.132 38.154 56.176 74.198] + [20.132 38.154 56.176 74.198 92.22 ]) / 2

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.hist(x2, bins=n_classes, edgecolor="black", alpha=0.7)
plt.title("Histogram")

plt.subplot(1, 2, 2)
plt.plot(class_centers, hist, marker="o", linestyle="-", color="blue")
plt.title("Polygon of frequencies")
plt.grid(True)

cumfreqs = cumfreq(x2, numbins=n_classes)
print(f"cumfreqs = {cumfreq(x2, numbins=n_classes)}")

plt.figure(figsize=(10, 6))
x_cdf = cumfreqs.lowerlimit + np.linspace(0, cumfreqs.binsize * cumfreqs.cumcount.size, cumfreqs.cumcount.size)
plt.plot(x_cdf, cumfreqs.cumcount / len(x2), marker="o", linestyle="-", color="green")
plt.title("Integral distribution function")
plt.grid(True)

plt.show()
# Out:
# cumfreqs = CumfreqResult(cumcount=array([2., 3., 4., 5., 8.]), lowerlimit=-9.15375, binsize=22.5275, extrapoints=0)

# %%
# Вхідні дані
data = np.array([2.11, 92.22, 82.43, 13.70, 53.42, 72.63, 11.723, 84.2])

# Гістограма
plt.hist(data, bins='auto')
plt.show()

# Статистики
mean = np.mean(data)
std = np.std(data)
skew = stats.skew(data)
kurtosis = stats.kurtosis(data)

# Перевірка на нормальність
_, p_value = stats.shapiro(data)
print("p-value for Shapiro-Wilk test:", p_value)

# Якщо p-value > 0.05, то гіпотеза про нормальність не відхиляється
# Out:
# p-value for Shapiro-Wilk test: 0.10896789879522722
